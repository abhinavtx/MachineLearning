# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
## It is an extension of simple linear regression, with multiple independent columns
## Using a function makeregression to make a new random dataset aimed for regression training

# %%
from sklearn.datasets import make_regression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
x,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'Feature1':x[:,0], 'Feature2' : x[:,1], "Target" : y })
df.sample(7)
# Out:
#     Feature1  Feature2      Target
# 58 -1.449113 -0.552827 -152.121983
# 78 -0.532380 -0.165882  -23.325919
# 0   0.155152  0.969789  162.290225
# 96 -0.627007  1.086620   34.479878
# 88 -0.146002  0.194485  -35.178186
# 17 -0.803678 -1.548965 -231.609847
# 55  0.946146 -0.541035   93.225456

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42, shuffle = True)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predicted =  lr.predict(x_test)
y_predicted
# Out:
# array([  89.49412438, -265.17925655,  144.25962323,  138.19371191,
#         266.23718474,  233.24923521,  228.43662943,  192.31590858,
#          41.39449794,  103.62939592,  106.75827574,   80.74005906,
#        -160.0443977 ,  -37.70638518,   82.56661534,  -10.56187024,
#         -29.88959815, -149.82067013,   -4.51050969,  -46.4207805 ])

# %%
print("Now printing the errors : ")
print("MAE",mean_absolute_error(y_test,y_predicted))
print("MSE",mean_squared_error(y_test,y_predicted))
print("R2 score",r2_score(y_test,y_predicted))
# Out:
# Now printing the errors :
# MAE 50.64986303788257
# MSE 3482.3248533175947
# R2 score 0.7815895924311158

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
plt.scatter(df['Feature1'], df['Target'], label = 'Feature1')
plt.scatter(df['Feature2'], df['Target'], label = 'Feature1')
plt.plot(x_train,lr.predict(x_train), color = 'red')
