# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
df.sample(7)
df.shape
# Out:
# (2000, 21)

# %%
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
dfTest = pd.read_csv('test.csv')
dfTest.sample(7)
# Out:
#       id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 82    83           1075     1          1.9         0   0       0          36
# 817  818           1057     1          0.5         0   4       1          42
# 788  789            519     1          2.0         1  11       1          33
# 839  840            922     0          2.7         1   0       1           3
# 811  812           1825     1          2.3         0   9       1          27
# 743  744           1590     1          2.4         0   5       0          15
# 818  819           1247     0          0.8         1  16       0          24
#
#      m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 82     0.6        127  ...   3       1335      1427  3870     8     3
# 817    0.7        112  ...   7        809       824  2688     6     3
# 788    0.7        135  ...  12        527       889   889    19     3
# 839    0.5        100  ...   0        253      1364  3910    18     8
# ...

# %%
dfTest.isna().sum()
# Out:
# id               0
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
dfTest.drop_duplicates(inplace=True)
dfTest.drop(columns='id', inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with 7 independent variables and 1 dependent variable
# Specify the features and the target variable
features = df.iloc[:, :-1]  # Select all columns except the last one
target = df.iloc[:, -1]     # Select the last column


# Plot distribution curves for each feature based on the target variable

for i in range(0,(len(features.columns)-1),2):
    plt.figure(figsize=(16,5))
    plt.subplot(1,2,1)
    sns.distplot(df[features.columns[i]])

    plt.subplot(1,2,2)
    sns.distplot(df[features.columns[i+1]])
    #sns.displot(df, x=column, hue=target.name, kind="kde", fill=True)
    plt.show()
# Out:
# C:\Users\abhinav.aggarwal\AppData\Local\Temp\ipykernel_15952\1215489124.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[features.columns[i]])
# C:\Users\abhinav.aggarwal\AppData\Local\Temp\ipykernel_15952\1215489124.py:18: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# Calculate the IQR for each feature
Q1 = features.quantile(0.25)
Q3 = features.quantile(0.75)
IQR = Q3 - Q1

# Identify outliers based on the IQR method
outliers = ((features < (Q1 - 1.5 * IQR)) | (features > (Q3 + 1.5 * IQR))).any(axis=1)

# Display the rows with outliers
df_outliers = df[outliers]

df_outliers
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 10              769     1          2.9         1   0       0           9
# 19              682     1          0.5         0   4       0          19
# 22             1949     0          2.6         1   4       0          47
# 30             1579     1          0.5         1   0       0           5
# ...             ...   ...          ...       ...  ..     ...         ...
# 1981           1454     0          2.6         0   8       0           6
# 1982           1784     0          1.6         0   4       0          41
# 1983           1262     0          1.8         1  12       0          34
# 1988           1547     1          2.9         0   2       0          57
# 1989            586     0          2.8         0   2       0          15
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
# Set the lower and upper bounds for capping
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Apply capping to values beyond the bounds
capped_features = features.clip(lower=lower_bound, upper=upper_bound, axis=1)

# Combine capped features and target into a single DataFrame
df_capped = pd.concat([capped_features, target], axis=1)

# Display the DataFrame after capping
df = df_capped
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
import pandas as pd

# Assuming 'df' is your DataFrame with multiple independent variables
# Specify the features
features = df.iloc[:, :-1]  # Select all columns except the last one

# Calculate the correlation matrix
correlation_matrix = features.corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Create a heatmap for better visualization
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# Correlation Matrix:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.032119
# blue                0.011252  1.000000     0.021419  0.035198  0.003712
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000897
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029944
# fc                  0.032119  0.003712    -0.000897 -0.029944  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.017395
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.028623
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001102
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.022640
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.012269
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.645716
# px_height           0.014900 -0.006897    -0.014519 -0.020864 -0.011983
# ...

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=42,shuffle=True)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x_train)
x_train = sc.transform(x_train)
x_test = sc.transform(x_test)
x = sc.transform(x)

# %%
from sklearn.decomposition import PCA

# Fit PCA
pca = PCA().fit(x_train)

# Plot cumulative explained variance ratio
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.grid(True)
plt.show()

# %%
## So making number of components as 6
pca = PCA(n_components = 15)
x_train = pca.fit_transform(x_train)
x_test = pca.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
lrPredicted = lr.predict(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knnClass = KNeighborsClassifier(n_neighbors=5,weights='distance',metric='minkowski',algorithm='auto',p=2)
knnClass.fit(x_train,y_train)
knnPredicted = knnClass.predict(x_test)

# %%
from sklearn.svm import SVC
classifierSVM = SVC(kernel = 'linear', random_state = 0)
classifierSVM.fit(x_train, y_train)
SVMPredicted = classifierSVM.predict(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
classifierNB = GaussianNB()
classifierNB.fit(x_train, y_train)
NBpredicted = classifierNB.predict(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
classifierDT = DecisionTreeClassifier(criterion = 'entropy', random_state = 0, max_depth = 6, min_samples_split = 5)
classifierDT.fit(x_train, y_train)
DTpredict = classifierDT.predict(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
classifierRF = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0, max_depth=8, min_samples_split=5)
classifierRF.fit(x_train, y_train)
RFpredict = classifierRF.predict(x_test)

# %%
NewDf = pd.DataFrame({ "Actual":y_test,'Logistic': lrPredicted, 'KNN':knnPredicted,'SVM':SVMPredicted})
NewDf
# Out:
#       Actual  Logistic  KNN  SVM
# 1860       0         0    0    0
# 353        2         2    1    2
# 1333       1         1    0    1
# 905        3         3    3    3
# 1289       1         1    1    1
# ...      ...       ...  ...  ...
# 965        3         3    2    3
# 1284       2         2    1    2
# 1739       1         1    1    1
# 261        1         1    0    1
# 535        2         2    1    2
#
# [400 rows x 4 columns]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report,precision_score,f1_score
cm1 = confusion_matrix(y_test, lrPredicted)
print("The confusion matrix for logistic regression is: \n",cm1)
print("The accuracy of logistic regression is ",accuracy_score(y_test, lrPredicted)*100,"%")
# Out:
# The confusion matrix for logistic regression is:
#  [[ 98   7   0   0]
#  [  5  82   4   0]
#  [  0   4  81   7]
#  [  0   0   2 110]]
# The accuracy of logistic regression is  92.75 %

# %%
## This is the cross validation score
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = lr, X = x_train, y = y_train, cv = 10)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy: 91.44 %
# Standard Deviation: 1.19 %

# %%
cm2 = confusion_matrix(y_test, knnPredicted)
print("The confusion matrix for knn is: \n",cm2)
print("The accuracy of knn is ",accuracy_score(y_test, knnPredicted)*100,"%")
# Out:
# The confusion matrix for knn is:
#  [[70 25 10  0]
#  [24 33 28  6]
#  [ 3 33 39 17]
#  [ 0  8 32 72]]
# The accuracy of knn is  53.5 %

# %%
cm3 = confusion_matrix(y_test, NBpredicted)
print("The confusion matrix for knn is: \n",cm3)
print("The accuracy of naive bayes is ",accuracy_score(y_test, NBpredicted)*100,"%")
# Out:
# The confusion matrix for knn is:
#  [[89 16  0  0]
#  [ 8 63 20  0]
#  [ 0 22 57 13]
#  [ 0  0 26 86]]
# The accuracy of naive bayes is  73.75 %

# %%
cm4 = confusion_matrix(y_test, SVMPredicted)
print("The confusion matrix for SVM is: \n",cm4)
print("The accuracy of SVM is ",accuracy_score(y_test, SVMPredicted)*100,"%")
# Out:
# The confusion matrix for SVM is:
#  [[ 99   6   0   0]
#  [  4  82   5   0]
#  [  0   6  80   6]
#  [  0   0   5 107]]
# The accuracy of SVM is  92.0 %

# %%
## This is the cross validation score
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifierSVM, X = x_train, y = y_train, cv = 10)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy: 90.75 %
# Standard Deviation: 1.60 %

# %%
cm5 = confusion_matrix(y_test, DTpredict)
print("The confusion matrix for Decision Tree is: \n",cm5)
print("The accuracy of Decision Tree is ",accuracy_score(y_test, DTpredict)*100,"%")
# Out:
# The confusion matrix for Decision Tree is:
#  [[80 24  1  0]
#  [23 42 24  2]
#  [ 3 23 49 17]
#  [ 0  4 29 79]]
# The accuracy of Decision Tree is  62.5 %

# %%
cm6 = confusion_matrix(y_test, RFpredict)
print("The confusion matrix for Random Forest is: \n",cm6)
print("The accuracy of Random Forest is ",accuracy_score(y_test, RFpredict)*100,"%")
# Out:
# The confusion matrix for Random Forest is:
#  [[86 17  2  0]
#  [20 47 22  2]
#  [ 4 17 43 28]
#  [ 0  2 22 88]]
# The accuracy of Random Forest is  66.0 %

# %%
## Now using hyperparametr tuning for logistic regression
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  
    'penalty': ['l1', 'l2'],               
    'solver': ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'],  
    'max_iter': [100, 200, 300]
}

# %%
from sklearn.model_selection import RandomizedSearchCV
randomSearch = RandomizedSearchCV(lr, param_grid, cv=10, scoring='accuracy')

# Fit the model to the data
randomSearch.fit(x_train, y_train)
# Out:
# c:\Users\abhinav.aggarwal\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\abhinav.aggarwal\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\abhinav.aggarwal\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\abhinav.aggarwal\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
lrHyperParam = randomSearch.best_params_
print("The hyperparametrs for logistic regression are: ",randomSearch.best_params_)
print("The final accuracy score is: ",randomSearch.best_score_*100,"%")
## This is the final accuracy after cross validation and hyperparamter tuning
# Out:
# The hyperparametrs for logistic regression are:  {'solver': 'saga', 'penalty': 'l1', 'max_iter': 100, 'C': 100}
# The final accuracy score is:  91.625 %

# %%
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV
param_distributions = {
    'C': uniform(0.1, 10),
    'gamma': uniform(0.1, 1),
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid']
}

# Perform Randomized Search Cross Validation
random_search = RandomizedSearchCV(estimator=classifierSVM, param_distributions=param_distributions,
                                   n_iter=10, cv=5, random_state=42)
random_search.fit(x_train, y_train)

# Print the best parameters found
print("Best parameters found: ", random_search.best_params_)

# Evaluate the model with the best parameters on the test set
best_model = random_search.best_estimator_
accuracy = best_model.score(x_test, y_test)
print("Accuracy on test set: ", accuracy)
# Out:
# Best parameters found:  {'C': 0.17066305219717406, 'gamma': 0.12306242504141576, 'kernel': 'poly'}
# Accuracy on test set:  0.7825

# %%
print('')
