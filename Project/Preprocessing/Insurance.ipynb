# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('insurance_claims.csv')
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
df.replace('?',np.nan,inplace=True)

# %%
def custom_describe(data):
    """
    Generate a custom description of a DataFrame including basic statistics,
    missing values count, unique values count, outliers count, and data types.
 
    Parameters:
    - data (pd.DataFrame): The pandas DataFrame to be described.
 
    Returns:
    pd.DataFrame: A custom description DataFrame with the following columns:
    - data_type: Data types for each column.
    - mean: Mean value for each numeric column.
    - std: Standard deviation for each numeric column.
    - missing_values: Count of missing values for each column.
    - unique_values: Count of unique values for each column.
    - outliers: Count of outliers for each numeric column.
    """
    # Basic statistics
    desc_stats = data.describe()
 
    # Missing values count
    missing_values = data.isnull().mean()
 
    # Unique values count
    unique_values = data.nunique()
 
    # Identify numeric columns
    numeric_cols = data.select_dtypes(include=['number']).columns
 
    # Calculate IQR and identify outliers for each numeric column
    outliers = {}
    for col in numeric_cols:
        q1 = desc_stats.loc['25%', col]
        q3 = desc_stats.loc['75%', col]
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        outliers[col] = ((data[col] < lower_bound) | (data[col] > upper_bound)).sum()
 
    # Get data types for each column
    data_types = data.dtypes
   
    # Combine all information
    custom_description = pd.DataFrame({
        'data_type': data_types,
        'mean': desc_stats.loc['mean'],
        'std': desc_stats.loc['std'],
        'missing_values_Average': missing_values,
        'unique_values': unique_values,
        'outliers': outliers
    })
    return custom_description

# %%
custom_describe(df)
# Out:
#                             data_type          mean           std  \
# _c39                          float64           NaN           NaN
# age                             int64  3.894800e+01  9.140287e+00
# authorities_contacted          object           NaN           NaN
# auto_make                      object           NaN           NaN
# auto_model                     object           NaN           NaN
# auto_year                       int64  2.005103e+03  6.015861e+00
# bodily_injuries                 int64  9.920000e-01  8.201272e-01
# capital-gains                   int64  2.512610e+04  2.787219e+04
# capital-loss                    int64 -2.679370e+04  2.810410e+04
# collision_type                 object           NaN           NaN
# fraud_reported                 object           NaN           NaN
# incident_city                  object           NaN           NaN
# incident_date                  object           NaN           NaN
# incident_hour_of_the_day        int64  1.164400e+01  6.951373e+00
# incident_location              object           NaN           NaN
# incident_severity              object           NaN           NaN
# incident_state                 object           NaN           NaN
# incident_type                  object           NaN           NaN
# injury_claim                    int64  7.433420e+03  4.880952e+03
# insured_education_level        object           NaN           NaN
# insured_hobbies                object           NaN           NaN
# insured_occupation             object           NaN           NaN
# insured_relationship           object           NaN           NaN
# insured_sex                    object           NaN           NaN
# insured_zip                     int64  5.012145e+05  7.170161e+04
# months_as_customer              int64  2.039540e+02  1.151132e+02
# number_of_vehicles_involved     int64  1.839000e+00  1.018880e+00
# police_report_available        object           NaN           NaN
# policy_annual_premium         float64  1.256406e+03  2.441674e+02
# policy_bind_date               object           NaN           NaN
# policy_csl                     object           NaN           NaN
# policy_deductable               int64  1.136000e+03  6.118647e+02
# policy_number                   int64  5.462386e+05  2.570630e+05
# policy_state                   object           NaN           NaN
# property_claim                  int64  7.399570e+03  4.824726e+03
# property_damage                object           NaN           NaN
# total_claim_amount              int64  5.276194e+04  2.640153e+04
# umbrella_limit                  int64  1.101000e+06  2.297407e+06
# vehicle_claim                   int64  3.792895e+04  1.888625e+04
# witnesses                       int64  1.487000e+00  1.111335e+00
#
#                              missing_values_Average  unique_values  outliers
# _c39                                          1.000              0       0.0
# age                                           0.000             46       4.0
# authorities_contacted                         0.091              4       NaN
# auto_make                                     0.000             14       NaN
# auto_model                                    0.000             39       NaN
# auto_year                                     0.000             21       0.0
# bodily_injuries                               0.000              3       0.0
# capital-gains                                 0.000            338       0.0
# capital-loss                                  0.000            354       0.0
# collision_type                                0.178              3       NaN
# fraud_reported                                0.000              2       NaN
# incident_city                                 0.000              7       NaN
# incident_date                                 0.000             60       NaN
# incident_hour_of_the_day                      0.000             24       0.0
# incident_location                             0.000           1000       NaN
# incident_severity                             0.000              4       NaN
# incident_state                                0.000              7       NaN
# incident_type                                 0.000              4       NaN
# injury_claim                                  0.000            638       0.0
# insured_education_level                       0.000              7       NaN
# insured_hobbies                               0.000             20       NaN
# insured_occupation                            0.000             14       NaN
# insured_relationship                          0.000              6       NaN
# insured_sex                                   0.000              2       NaN
# insured_zip                                   0.000            995       0.0
# months_as_customer                            0.000            391       0.0
# number_of_vehicles_involved                   0.000              4       0.0
# police_report_available                       0.343              2       NaN
# policy_annual_premium                         0.000            991       9.0
# policy_bind_date                              0.000            951       NaN
# policy_csl                                    0.000              3       NaN
# policy_deductable                             0.000              3       0.0
# policy_number                                 0.000           1000       0.0
# policy_state                                  0.000              3       NaN
# property_claim                                0.000            626       6.0
# property_damage                               0.360              2       NaN
# total_claim_amount                            0.000            763       1.0
# umbrella_limit                                0.000             11     202.0
# vehicle_claim                                 0.000            726       0.0
# witnesses                                     0.000              4       0.0

# %%
df.drop(columns='_c39',inplace=True)

# %%
columns_with_null = df.columns[df.isnull().any()]

# %%
columns_with_null
# Out:
# Index(['collision_type', 'authorities_contacted', 'property_damage',
#        'police_report_available'],
#       dtype='object')

# %%
val = df.loc[:,['collision_type', 'authorities_contacted', 'property_damage','police_report_available']]
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy = 'most_frequent')
df.loc[:,['collision_type', 'authorities_contacted', 'property_damage','police_report_available']] =  pd.DataFrame(imp.fit_transform(val), columns = columns_with_null)

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0       466132  ...         2                     YES              71610
# 1       468176  ...         0                      NO               5070
# 2       430632  ...         3                      NO              34650
# 3       608117  ...         2                      NO              63400
# 4       610706  ...         1                      NO               6500
#
#   injury_claim property_claim  vehicle_claim  auto_make auto_model auto_year  \
# 0         6510          13020          52080       Saab        92x      2004
# 1          780            780           3510   Mercedes       E400      2007
# 2         7700           3850          23100      Dodge        RAM      2007
# 3         6340           6340          50720  Chevrolet      Tahoe      2014
# 4         1300            650           4550     Accura        RSX      2009
#
#   fraud_reported
# 0              Y
# 1              Y
# 2              N
# 3              Y
# 4              N
#
# [5 rows x 39 columns]
